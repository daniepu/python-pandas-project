# %% [markdown]
# # Simple Company
#
# Add logo

# %% [markdown]
# ## Hide\show the code

# %%
# %%html
# <script>
# function hidecode() {
#     x=document.getElementsByClassName("input");
#     for (i = 0; i < x.length; i++) {
#         x[i].style.display="none";
#     }
#     x=document.getElementsByClassName("output_stderr");
#     for (i = 0; i < x.length; i++) {
#         x[i].style.display="none";
#     }
# }
# function showcode() {
#     x=document.getElementsByClassName("input");
#     for (i = 0; i < x.length; i++) {
#         x[i].style.display="";
#     }
#     x=document.getElementsByClassName("output_stderr");
#     for (i = 0; i < x.length; i++) {
#         x[i].style.display="";
#     }
# }
# </script>
# <input class="box"  type="button" onclick="hidecode()" value="Hide code"/>
# <input class="box"  type="button" onclick="showcode()" value="Show code"/>
# <body onload="hidecode()">
# Out:
# <script>
# function hidecode() {
#     x=document.getElementsByClassName("input");
#     for (i = 0; i < x.length; i++) {
#         x[i].style.display="none";
#     }
#     x=document.getElementsByClassName("output_stderr");
#     for (i = 0; i < x.length; i++) {
#         x[i].style.display="none";
#     }
# }
# function showcode() {
#     x=document.getElementsByClassName("input");
#     for (i = 0; i < x.length; i++) {
#         x[i].style.display="";
#     }
#     x=document.getElementsByClassName("output_stderr");
#     for (i = 0; i < x.length; i++) {
#         x[i].style.display="";
#     }
# }
# </script>
# <input class="box"  type="button" onclick="hidecode()" value="Hide code"/>
# <input class="box"  type="button" onclick="showcode()" value="Show code"/>
# <body onload="hidecode()">

# %% [markdown]
# ## Import packages
# pandas -(Add more information...)

# %%
import pandas as pd

# %% [markdown]
# ## Read the data (Add more information...)

# %%
df_2019 = pd.read_csv(r'C:\Users\orans\Documents\oran\Lectures\python_course\תרגילים\תרגיל סיום\Training_Dataset.xlsx - 2019 Sales.csv', engine='python')
df_2019.head()
# Out:
#    Order ID Product ID Location ID Sales Person ID Customer ID Purchase Date  \
# 0  OID10004    PID2029        A142         EMP1019       C1078     2/23/2019
# 1  OID10014    PID2079        A152         EMP1041       C1073     2/24/2019
# 2  OID10027    PID2062        A126         EMP1001       C1256     3/13/2019
# 3  OID10032    PID2083        A156         EMP1025       C1342     1/17/2019
# 4  OID10042    PID2100        A147         EMP1019       C1267      1/3/2019
#
#    Quantity  Price Product Name  Unit Cost        ...         Latitude  \
# 0         4   1848   Product 30       1294        ...         34.57943
# 1         1   1725   Product 80       1363        ...         34.10834
# 2         1   2464   Product 63       1774        ...         33.66030
# 3         1   2141   Product 84       1777        ...         37.33939
# 4         1    799  Product 101        455        ...         37.93576
#
# ...

# %% [markdown]
# ## Information on the data:

# %%
print("Number of records: {}".format(len(df_2019)))
print("Number of columns: {}".format(len(df_2019.columns)))
print(df_2019.describe())
# .....
# Out:
# Number of records: 1000
# Number of columns: 28
#           Quantity        Price    Unit Cost  Discount        Taxes  \
# count  1000.000000  1000.000000  1000.000000    1000.0  1000.000000
# mean      1.900000  1264.271000   852.761000       0.0   189.640650
# std       1.079428   726.207475   510.834356       0.0   108.931121
# min       1.000000    35.000000    22.000000       0.0     5.250000
# 25%       1.000000   584.000000   420.000000       0.0    87.600000
# 50%       1.000000  1353.000000   807.000000       0.0   202.950000
# 75%       3.000000  1848.000000  1261.000000       0.0   277.200000
# max       4.000000  2497.000000  1965.000000       0.0   374.550000
#
#           Latitude    Longitude    Area Code  Area Population  \
# count  1000.000000  1000.000000  1000.000000     1.000000e+03
# mean     35.199076  -119.191143   681.604000     2.949273e+05
# std       1.883049     1.942350   199.158025     5.684556e+05
# ...

# %% [markdown]
# ## Let’s check whether our data set has been imported as we would expect.

# %%
df_2019.dtypes
# Out:
# Order ID               object
# Product ID             object
# Location ID            object
# Sales Person ID        object
# Customer ID            object
# Purchase Date          object
# Quantity                int64
# Price                   int64
# Product Name           object
# Unit Cost               int64
# Discount                int64
# Taxes                 float64
# Category ID            object
# Category Name          object
# Area Name              object
# County                 object
# State Code             object
# State                  object
# Latitude              float64
# Longitude             float64
# Area Code               int64
# Area Population         int64
# Area Households         int64
# Area Median Income      int64
# Customer Name          object
# Age                     int64
# Gender                 object
# Salesperson Name       object
# dtype: object

# %%
## fix column if needed

# %% [markdown]
# ## Let's check what is the max price of a product:

# %%
df_2019.sort_values(by = "Price", ascending = False)
# Out:
#      Order ID Product ID Location ID Sales Person ID Customer ID  \
# 68   OID10808    PID2027        A146         EMP1011       C1442
# 747  OID21164    PID2027        A169         EMP1018       C1658
# 814  OID22189    PID2027        A118         EMP1031       C1523
# 303  OID14244    PID2027        A163         EMP1014       C1304
# 33   OID10324    PID2027        A108         EMP1002       C1582
# 504  OID17442    PID2027        A139         EMP1012       C1212
# 63   OID10722    PID2027        A170         EMP1025       C1035
# 966  OID24403    PID2027        A171         EMP1042       C1351
# 14   OID10155    PID2027        A111         EMP1024       C1176
# 886  OID23392    PID2027        A121         EMP1029       C1053
# 675  OID20041    PID2055        A156         EMP1021       C1070
# 73   OID10925    PID2055        A151         EMP1012       C1185
# 416  OID16142    PID2055        A138         EMP1019       C1126
# ...

# %% [markdown]
# We can see that the max price of product is 2497 ........

# %%
df_2019.get_dtype_counts()
# Out:
# float64     3
# int64       9
# object     16
# dtype: int64
